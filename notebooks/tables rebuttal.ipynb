# %%
import pandas as pd
from pathlib import Path

# %%
def load_results_table(results_dir, methods_list, use_coords, use_demographic, file_name="aggregated_results.json"):
    agg_list = []
    for method in methods_list:
        if use_demographic and use_coords:
            folder_name = f"{method}_coords_demographic_radiomics"
        elif use_demographic and not use_coords:
            folder_name = f"{method}_demographic_radiomics"
        elif not use_demographic and use_coords:
            folder_name = f"{method}_coords_radiomics"
        else:
            folder_name = f"{method}_radiomics"
        
        if method == "ml_models":
            folder_name = f"Rebuttal/{folder_name}"
        aggregated_result_dir = Path(results_dir)/folder_name / file_name
        df = pd.read_json(aggregated_result_dir)
        agg_list.append(df)
    final_df = pd.concat(agg_list, ignore_index=True)
    # final_df = final_df[['model', 'Accuracy_Mean', 'ROC_AUC_Mean']]
    display(final_df)
    # print("Average across models:")
    # display(pd.DataFrame(final_df.mean(numeric_only=True)).T)

# %% [markdown]
# # Five Fold Cross Validation for Center 1 Dataset

# %%
models = ["transformer", "deep_sets", "mil", "set_transformer", "graph", 'ml_models']
new_models = ["transformer", "deep_sets", "mil", "set_transformer", "graph"]

# %%
print("Radiomics Features:")
load_results_table("../Results", models, use_coords=False, use_demographic=False)

# %%
print("Radiomics + demographic Features:")
load_results_table("../Results", models, use_coords=False, use_demographic=True)

# %%
print("Radiomics + coords Features:")
load_results_table("../Results", models, use_coords=True, use_demographic=False)

# %%
print("Radiomics + coords + demographic Features:")
load_results_table("../Results", models, use_coords=True, use_demographic=True)
# Out:
# Radiomics + coords + demographic Features:
#                   model  Accuracy_Mean  Accuracy_STD  ROC_AUC_Mean  \
# 0           transformer       0.818547      0.040170      0.910149
# 1             deep_sets       0.825643      0.048212      0.909966
# 2                   mil       0.811405      0.059006      0.903351
# 3       set_transformer       0.818087      0.079479      0.878518
# 4                 graph       0.840341      0.071940      0.887535
# 5              AdaBoost       0.724034      0.043101      0.846978
# 6              CatBoost       0.744479      0.053491      0.843126
# 7           Extra Trees       0.744479      0.071299      0.840374
# 8     Gradient Boosting       0.744264      0.043327      0.831949
# 9   Logistic Regression       0.678242      0.047813      0.631577
# 10                  MLP       0.757382      0.076380      0.829757
# 11        Random Forest       0.710901      0.042343      0.836630
# 12     SVM (RBF kernel)       0.669996      0.081640      0.697921
# 13               TabPFN       0.825428      0.028164      0.890929
# 14              XGBoost       0.784509      0.055173      0.844134
# 15  k-Nearest Neighbors       0.710011      0.089711      0.718951
# 16             lightGBM       0.811420      0.058560      0.853738
#
#     ROC_AUC_STD  Precision_Mean  Precision_STD  Recall_Mean  Recall_STD  \
# 0      0.052559        0.793397       0.053054     0.929412    0.049215
# 1      0.047602        0.833889       0.042781     0.870588    0.096657
# 2      0.056494        0.800496       0.031636     0.894118    0.105227
# 3      0.063525        0.810693       0.067945     0.894118    0.064438
# 4      0.069635        0.860410       0.104882     0.870588    0.076696
# 5      0.031896        0.715379       0.019849     0.858824    0.067069
# 6      0.016225        0.753167       0.032073     0.823529    0.093008
# 7      0.016731        0.738421       0.048255     0.858824    0.106858
# 8      0.021443        0.787371       0.038129     0.764706    0.110049
# 9      0.048344        0.668768       0.023462     0.858824    0.089210
# 10     0.054671        0.756116       0.036254     0.847059    0.114668
# 11     0.018640        0.751428       0.078637     0.764706    0.093008
# 12     0.024336        0.640834       0.052123     0.976471    0.052613
# 13     0.038022        0.856460       0.022815     0.835294    0.064438
# 14     0.062187        0.820640       0.018099     0.800000    0.121979
# 15     0.115866        0.719223       0.075121     0.823529    0.117647
# 16     0.061351        0.843873       0.053055     0.823529    0.058824
#
#     Specificity_Mean  Specificity_STD  F1_Score_Mean  F1_Score_STD
# 0           0.672344         0.102577       0.854386      0.028481
# 1           0.768498         0.065482       0.848954      0.047101
# 2           0.703114         0.062688       0.842385      0.053786
# 3           0.714835         0.132445       0.849641      0.061613
# 4           0.803114         0.154870       0.861640      0.064136
# 5           0.545055         0.049359       0.779892      0.035930
# 6           0.641209         0.059349       0.784819      0.050484
# 7           0.594872         0.090926       0.791811      0.061280
# 8           0.717399         0.096618       0.770670      0.052135
# 9           0.436996         0.022925       0.751131      0.047065
# 10          0.640110         0.042639       0.797452      0.067992
# 11          0.639744         0.179853       0.750912      0.026305
# 12          0.257509         0.191160       0.772987      0.047683
# 13          0.813553         0.033856       0.844378      0.029436
# 14          0.766117         0.051525       0.805438      0.066166
# 15          0.561722         0.163229       0.763572      0.073610
# 16          0.795604         0.072805       0.833104      0.051318

# %% [markdown]
# # Second dataset

# %%
print("Radiomics Features:")
load_results_table("../Results", models, use_coords=False, use_demographic=False, file_name="center2_aggregated_results.json")

# %%
print("Radiomics + demographic Features:")
load_results_table("../Results", models, use_coords=False, use_demographic=True, file_name="center2_aggregated_results.json")

# %%
print("Radiomics + coords Features:")
load_results_table("../Results", models, use_coords=True, use_demographic=False, file_name="center2_aggregated_results.json")

# %%
print("Radiomics + demographic + coords Features:")
load_results_table("../Results", models, use_coords=True, use_demographic=True, file_name="center2_aggregated_results.json")

# %% [markdown]
# # Test Time Adaptation (TTA) on Center 2 data

# %% [markdown]
# ## TENT method for TTA

# %%
print("Radiomics:")
print("TTA - Center2: Tent")
load_results_table("../Results", ["transformer", "mil", "deep_sets", "graph", 'set_transformer'], use_coords=False, use_demographic=False, file_name="tta_tent_center2_aggregated_results.json")
print("TTA - Center2: Norm ")
load_results_table("../Results", ["transformer", "mil", "deep_sets", "graph", 'set_transformer'], use_coords=False, use_demographic=False, file_name="tta_norm_center2_aggregated_results.json")
# Out:
# Radiomics:
# TTA - Center2: Tent
#              model  Accuracy_Mean  Accuracy_STD  ROC_AUC_Mean  ROC_AUC_STD  \
# 0      transformer         0.6000      0.060596      0.680682     0.085030
# 1              mil         0.6200      0.025921      0.684975     0.037660
# 2        deep_sets         0.6100      0.051841      0.654167     0.034316
# 3            graph         0.5925      0.062249      0.641035     0.054791
# 4  set_transformer         0.6450      0.018957      0.674874     0.008146
#
#    Precision_Mean  Precision_STD  Recall_Mean  Recall_STD  Specificity_Mean  \
# 0        0.529594       0.046364     0.861111    0.186339          0.386364
# 1        0.549262       0.018349     0.866667    0.036218          0.418182
# 2        0.548385       0.042120     0.750000    0.070820          0.495455
# 3        0.531582       0.044145     0.894444    0.110065          0.345455
# 4        0.564110       0.014201     0.933333    0.042127          0.409091
#
#    Specificity_STD  F1_Score_Mean  F1_Score_STD
# 0         0.066261       0.652743      0.093522
# 1         0.025913       0.672322      0.023732
# 2         0.043717       0.633374      0.052271
# 3         0.151098       0.663507      0.042951
# 4         0.045455       0.702799      0.015609
# TTA - Center2: Norm
#              model  Accuracy_Mean  Accuracy_STD  ROC_AUC_Mean  ROC_AUC_STD  \
# 0      transformer          0.625      0.055199      0.655051     0.039166
# 1              mil          0.575      0.064348      0.604040     0.075626
# 2        deep_sets          0.540      0.020540      0.582386     0.059842
# 3            graph          0.545      0.064711      0.587374     0.080442
# 4  set_transformer          0.570      0.049687      0.618687     0.061675
#
#    Precision_Mean  Precision_STD  Recall_Mean  Recall_STD  Specificity_Mean  \
# 0        0.577434       0.049333     0.683333    0.227879          0.577273
# 1        0.509231       0.069668     0.355556    0.290274          0.754545
# 2        0.476775       0.039370     0.388889    0.302383          0.663636
# 3        0.486533       0.069683     0.511111    0.380160          0.572727
# 4        0.507241       0.083733     0.338889    0.248762          0.759091
#
#    Specificity_STD  F1_Score_Mean  F1_Score_STD
# 0         0.198522       0.605689      0.117767
# 1         0.128966       0.385296      0.206638
# 2         0.231996       0.382706      0.194361
# 3         0.336486       0.449455      0.196331
# 4         0.127151       0.377197      0.196150

# %%
print("Radiomics + demographic Features:")
print("TTA - Center2: Tent")
load_results_table("../Results", ["transformer", "mil", "deep_sets", "graph", 'set_transformer'], use_coords=False, use_demographic=True, file_name="tta_tent_center2_aggregated_results.json")
print("TTA - Center2: Norm ")
load_results_table("../Results", ["transformer", "mil", "deep_sets", "graph", 'set_transformer'], use_coords=False, use_demographic=True, file_name="tta_norm_center2_aggregated_results.json")

# %%
print("Radiomics  + coords Features:")
print("TTA - Center2: Tent")
load_results_table("../Results", ["transformer", "mil", "deep_sets", "graph", 'set_transformer'], use_coords=True, use_demographic=False, file_name="tta_tent_center2_aggregated_results.json")
print("TTA - Center2: Norm ")
load_results_table("../Results", ["transformer", "mil", "deep_sets", "graph", 'set_transformer'], use_coords=True, use_demographic=False, file_name="tta_norm_center2_aggregated_results.json")

# %%
print("Radiomics + demographic + coords Features:")
print("TTA - Center2: Tent")
load_results_table("../Results", ["transformer", "mil", "deep_sets", "graph", 'set_transformer'], use_coords=True, use_demographic=True, file_name="tta_tent_center2_aggregated_results.json")
print("TTA - Center2: Norm ")
load_results_table("../Results", ["transformer", "mil", "deep_sets", "graph", 'set_transformer'], use_coords=True, use_demographic=True, file_name="tta_norm_center2_aggregated_results.json")

# %% [markdown]
# # comparision curves

# %%
def selected_methods_table(results_dir, methods_list, use_coords, use_demographic, ml_models=["AdaBoost", 'TabPFN'], file_name="aggregated_results.json"):
    agg_list = []
    for method in methods_list:
        if use_demographic and use_coords:
            folder_name = f"{method}_coords_demographic_radiomics"
        elif use_demographic and not use_coords:
            folder_name = f"{method}_demographic_radiomics"
        elif not use_demographic and use_coords:
            folder_name = f"{method}_coords_radiomics"
        else:
            folder_name = f"{method}_radiomics"
        
        if method == "ml_models":
            folder_name = f"Rebuttal/{folder_name}"
            
        aggregated_result_dir = Path(results_dir)/folder_name / file_name
        df = pd.read_json(aggregated_result_dir)
        # choose only ml models for ROC curves
        if method == "ml_models":
            df = df[df['model'].isin(ml_models)]
        agg_list.append(df)
    final_df = pd.concat(agg_list, ignore_index=True)
    # final_df = final_df[['model', 'Accuracy_Mean', 'ROC_AUC_Mean']]
    display(final_df)


selected_methods_table("../Results", models, use_coords=True, use_demographic=True)
# Out:
#              model  Accuracy_Mean  Accuracy_STD  ROC_AUC_Mean  ROC_AUC_STD  \
# 0      transformer       0.818547      0.040170      0.910149     0.052559
# 1        deep_sets       0.825643      0.048212      0.909966     0.047602
# 2              mil       0.811405      0.059006      0.903351     0.056494
# 3  set_transformer       0.818087      0.079479      0.878518     0.063525
# 4            graph       0.840341      0.071940      0.887535     0.069635
# 5         AdaBoost       0.724034      0.043101      0.846978     0.031896
# 6           TabPFN       0.825428      0.028164      0.890929     0.038022
#
#    Precision_Mean  Precision_STD  Recall_Mean  Recall_STD  Specificity_Mean  \
# 0        0.793397       0.053054     0.929412    0.049215          0.672344
# 1        0.833889       0.042781     0.870588    0.096657          0.768498
# 2        0.800496       0.031636     0.894118    0.105227          0.703114
# 3        0.810693       0.067945     0.894118    0.064438          0.714835
# 4        0.860410       0.104882     0.870588    0.076696          0.803114
# 5        0.715379       0.019849     0.858824    0.067069          0.545055
# 6        0.856460       0.022815     0.835294    0.064438          0.813553
#
#    Specificity_STD  F1_Score_Mean  F1_Score_STD
# 0         0.102577       0.854386      0.028481
# 1         0.065482       0.848954      0.047101
# 2         0.062688       0.842385      0.053786
# 3         0.132445       0.849641      0.061613
# 4         0.154870       0.861640      0.064136
# 5         0.049359       0.779892      0.035930
# 6         0.033856       0.844378      0.029436

# %%
import json
from typing import Any, Union

from scipy import stats

def load_json(path: str) -> Union[dict, list]:
    """Load a JSON file and return its Python object (usually dict or list)."""
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
def plot_cv_roc_compare_fancy(
    method_to_folds,
    title="5-Fold Cross-Validated ROC",
    n_grid=500,
    show_folds=False,
    show_band=True,
    show_chance=True,
    show_iso_tpr=False,
    legend_loc="lower right",
    savepath=None,
    dpi=300,
    ax=None,               # NEW
):
    plt.rcParams.update({
        "font.size": 12,
        "axes.titlesize": 14,
        "axes.labelsize": 12,
        "legend.fontsize": 10,
        "axes.spines.top": False,
        "axes.spines.right": False,
    })

    mean_fpr = np.linspace(0.0, 1.0, n_grid)

    created_fig = False
    if ax is None:
        fig, ax = plt.subplots(figsize=(8.6, 7.2))
        created_fig = True
    else:
        fig = ax.figure

    ax.set_title(title, pad=12)
    ax.grid(True, which="major", alpha=0.25)
    ax.grid(True, which="minor", alpha=0.10)
    ax.minorticks_on()

    if show_iso_tpr:
        for t in [0.2, 0.4, 0.6, 0.8]:
            ax.axhline(t, lw=0.8, alpha=0.15)

    if show_chance:
        ax.plot([0, 1], [0, 1], linestyle="--", lw=1.2, alpha=0.7, label="Chance")

    for method_name, folds in method_to_folds.items():
        tprs = []
        aucs = []

        for y_true, y_score in folds:
            y_true = np.asarray(y_true).astype(int)
            y_score = np.asarray(y_score)

            fpr, tpr, _ = roc_curve(y_true, y_score)
            fold_auc = auc(fpr, tpr)
            aucs.append(fold_auc)

            interp_tpr = np.interp(mean_fpr, fpr, tpr)
            interp_tpr[0] = 0.0
            tprs.append(interp_tpr)

            if show_folds:
                ax.plot(fpr, tpr, lw=1.0, alpha=0.12)

        tprs = np.vstack(tprs)
        mean_tpr = tprs.mean(axis=0)
        std_tpr = tprs.std(axis=0)
        mean_tpr[-1] = 1.0

        mean_auc = float(np.mean(aucs))
        std_auc = float(np.std(aucs))
        n = len(aucs)

        ci_low, ci_high = stats.t.interval(
                                0.95, df=n-1, loc=mean_auc, scale=std_auc/np.sqrt(n)
                            )

        label = (
                f"{method_name} | "
                f"AUC={mean_auc:.3f}±{std_auc:.3f} "
                f"(95% CI: {ci_low:.3f}–{ci_high:.3f})"
            )
        
        # Main mean curve (matplotlib default colors auto-cycle)
        (line,) = ax.plot(
            mean_fpr, mean_tpr, lw=2.8,
            label=label
        )

        if show_band:
            color = line.get_color()
            tpr_lower = np.clip(mean_tpr - std_tpr, 0.0, 1.0)
            tpr_upper = np.clip(mean_tpr + std_tpr, 0.0, 1.0)
            ax.fill_between(mean_fpr, tpr_lower, tpr_upper, alpha=0.14, color=color)

    ax.set_xlim(0.0, 1.0)
    ax.set_ylim(0.0, 1.05)
    ax.set_xlabel("False Positive Rate (1 - Specificity)")
    ax.set_ylabel("True Positive Rate (Sensitivity)")

    leg = ax.legend(loc=legend_loc, frameon=True, framealpha=0.9, borderpad=0.6)
    leg.get_frame().set_linewidth(0.6)

    if savepath is not None:
        fig.savefig(savepath, dpi=dpi, bbox_inches="tight")

    if created_fig:
        fig.tight_layout()
        plt.show()
from pathlib import Path  # make sure this exists

def comparision_plot_roc_curves(
    results_dir,
    methods_list,
    use_coords,
    use_demographic,
    ml_models=["AdaBoost", "TabPFN"],
    file_name="results_fold",
):
    # helper that runs your existing loading logic for a specific (coords, demographic) setting
    def build_method_folds(use_coords_local, use_demographic_local):
        method_folds = {}
        ml_folds = {}

        for method in methods_list:
            if use_demographic_local and use_coords_local:
                folder_name = f"{method}_coords_demographic_radiomics"
            elif use_demographic_local and not use_coords_local:
                folder_name = f"{method}_demographic_radiomics"
            elif not use_demographic_local and use_coords_local:
                folder_name = f"{method}_coords_radiomics"
            else:
                folder_name = f"{method}_radiomics"

            if method == "ml_models":
                folder_name = f"Rebuttal/{folder_name}"

            folds = []
            for i in range(5):
                fold_result_dir = Path(results_dir) / folder_name / f"fold_{i}" / f"{file_name}_{i}.json"
                fold_results = load_json(fold_result_dir)

                if method == "ml_models":
                    for mm in ml_models:
                        ml_folds.setdefault(mm, [])
                        ml_folds[mm].append([fold_results[mm]["y_true"], fold_results[mm]["y_prob"]])
                else:
                    folds.append([fold_results["y_true"], fold_results["y_prob"]])

            if method != "ml_models":
                method_folds[method] = folds

        # add age&gender once
        age_gender_folder_name = "Rebuttal/ml_models_age_gender"
        ml_folds.setdefault("AdaBoost - Demographic", [])
        for i in range(5):
            age_gender_file_dir = Path(results_dir) / age_gender_folder_name / f"fold_{i}" / f"{file_name}_{i}.json"
            age_gender_results = load_json(age_gender_file_dir)
            ml_folds["AdaBoost - Demographic"].append([
                age_gender_results["AdaBoost"]["y_true"],
                age_gender_results["AdaBoost"]["y_prob"]
            ])
        method_folds.update(ml_folds)
        return method_folds

    # ---- 2x2 subplots over the 4 folder variants ----
    fig, axs = plt.subplots(2, 2, figsize=(16, 12), sharex=True, sharey=True)

    configs = [
        (True,  True,  "coords + demographic + radiomics"),
        (False, True,  "demographic + radiomics"),
        (True,  False, "coords + radiomics"),
        (False, False, "radiomics only"),
    ]

    for ax, (c, d, subtitle) in zip(axs.ravel(), configs):
        method_folds = build_method_folds(use_coords_local=c, use_demographic_local=d)
        plot_cv_roc_compare_fancy(
            method_folds,
            title=subtitle,
            ax=ax,
            show_folds=False,
            show_band=False,
            show_chance=True,
            legend_loc="lower right",
        )

    # fig.suptitle("5-Fold CV ROC Comparison (All Feature Configurations)", y=1.02, fontsize=16)
    fig.tight_layout()
    fig.savefig("figures/roc_comparison_center1.png", dpi=300, bbox_inches="tight")

    plt.show()

comparision_plot_roc_curves("../Results", models, use_coords=True, use_demographic=True)

# %% [markdown]
# # Delong Test

# %%
import json, numpy as np, pandas as pd
from pathlib import Path
from scipy import stats

# ---------- DeLong ----------
def _mr(x):
    x = np.asarray(x); o = np.argsort(x); z = x[o]; n = len(x); r = np.zeros(n); i = 0
    while i < n:
        j = i
        while j < n and z[j] == z[i]: j += 1
        r[i:j] = 0.5 * (i + j - 1) + 1
        i = j
    out = np.empty(n); out[o] = r
    return out

def _fast_delong(preds, n_pos):
    m, n = n_pos, preds.shape[1] - n_pos
    pos, neg = preds[:, :m], preds[:, m:]
    tx = np.vstack([_mr(x) for x in pos]); ty = np.vstack([_mr(x) for x in neg]); tz = np.vstack([_mr(x) for x in preds])
    aucs = tz[:, :m].sum(1) / (m * n) - (m + 1) / (2 * n)
    v01 = (tz[:, :m] - tx) / n
    v10 = 1.0 - (tz[:, m:] - ty) / m
    return aucs, np.cov(v01) / m + np.cov(v10) / n

def delong_pvalue(y, s1, s2):
    y = np.asarray(y).astype(int); s1 = np.asarray(s1, float); s2 = np.asarray(s2, float)
    order = np.argsort(-y)
    aucs, cov = _fast_delong(np.vstack([s1[order], s2[order]]), int(y.sum()))
    var = max(cov[0,0] + cov[1,1] - 2 * cov[0,1], 1e-12)
    return 2 * stats.norm.sf(abs((aucs[0] - aucs[1]) / np.sqrt(var)))

# ---------- loading ----------
def load_json(p):
    with open(p, "r") as f: return json.load(f)

def collect_oof(results_dir, method, use_coords, use_demo, file_name="results_fold", ml_model=None):
    if method == "ml_models" and ml_model == "AdaBoost - Demographic":
        folder = "Rebuttal/ml_models_age_gender"
        ys, ps = [], []
        for i in range(5):
            d = load_json(Path(results_dir) / folder / f"fold_{i}" / f"{file_name}_{i}.json")
            ys += d["AdaBoost"]["y_true"]; ps += d["AdaBoost"]["y_prob"]
        return np.array(ys), np.array(ps)

    folder = (
        f"{method}_coords_demographic_radiomics" if use_coords and use_demo else
        f"{method}_demographic_radiomics" if use_demo else
        f"{method}_coords_radiomics" if use_coords else
        f"{method}_radiomics"
    )
    if method == "ml_models":
        folder = f"Rebuttal/{folder}"

    ys, ps = [], []
    for i in range(5):
        d = load_json(Path(results_dir) / folder / f"fold_{i}" / f"{file_name}_{i}.json")
        if method == "ml_models":
            ys += d[ml_model]["y_true"]; ps += d[ml_model]["y_prob"]
        else:
            ys += d["y_true"]; ps += d["y_prob"]
    return np.array(ys), np.array(ps)

# ---------- collect all settings ----------
results_dir = "../Results"
file_name = "results_fold"

preds = {
    ("Transformer", "coords+demo+radio"): collect_oof(results_dir, "transformer", True,  True,  file_name),
    ("Transformer", "demo+radio"):        collect_oof(results_dir, "transformer", False, True,  file_name),
    ("Transformer", "coords+radio"):      collect_oof(results_dir, "transformer", True,  False, file_name),
    ("Transformer", "radiomics"):         collect_oof(results_dir, "transformer", False, False, file_name),

    ("AdaBoost", "coords+demo+radio"):    collect_oof(results_dir, "ml_models",   True,  True,  file_name, "AdaBoost"),
    ("AdaBoost", "demo+radio"):           collect_oof(results_dir, "ml_models",   False, True,  file_name, "AdaBoost"),
    ("AdaBoost", "coords+radio"):         collect_oof(results_dir, "ml_models",   True,  False, file_name, "AdaBoost"),
    ("AdaBoost", "radiomics"):            collect_oof(results_dir, "ml_models",   False, False, file_name, "AdaBoost"),
    ("AdaBoost", "demographic only"):     collect_oof(results_dir, "ml_models",   False, True,  file_name, "AdaBoost - Demographic"),
}

# sanity check: same held-out labels everywhere
y0 = next(iter(preds.values()))[0]
for k, (y, _) in preds.items():
    assert np.array_equal(y0, y), f"Label mismatch in {k}"

# ---------- full p-value table ----------
idx = pd.MultiIndex.from_tuples(preds.keys(), names=["Model", "Config"])
pvals = pd.DataFrame(index=idx, columns=idx, dtype=float)

for r_name, (y_r, p_r) in preds.items():
    for c_name, (y_c, p_c) in preds.items():
        pvals.loc[r_name, c_name] = np.nan if r_name == c_name else delong_pvalue(y_r, p_r, p_c)

# prettier display
pvals = pvals.round(6)
# print(pvals)

# optional: nicer notebook display
display(pvals.style.format("{:.4f}", na_rep="—"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_4186d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Model</th>
#       <th id="T_4186d_level0_col0" class="col_heading level0 col0" colspan="4">Transformer</th>
#       <th id="T_4186d_level0_col4" class="col_heading level0 col4" colspan="5">AdaBoost</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Config</th>
#       <th id="T_4186d_level1_col0" class="col_heading level1 col0" >coords+demo+radio</th>
#       <th id="T_4186d_level1_col1" class="col_heading level1 col1" >demo+radio</th>
#       <th id="T_4186d_level1_col2" class="col_heading level1 col2" >coords+radio</th>
#       <th id="T_4186d_level1_col3" class="col_heading level1 col3" >radiomics</th>
#       <th id="T_4186d_level1_col4" class="col_heading level1 col4" >coords+demo+radio</th>
#       <th id="T_4186d_level1_col5" class="col_heading level1 col5" >demo+radio</th>
#       <th id="T_4186d_level1_col6" class="col_heading level1 col6" >coords+radio</th>
#       <th id="T_4186d_level1_col7" class="col_heading level1 col7" >radiomics</th>
#       <th id="T_4186d_level1_col8" class="col_heading level1 col8" >demographic only</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="index_name level1" >Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4186d_level0_row0" class="row_heading level0 row0" rowspan="4">Transformer</th>
#       <th id="T_4186d_level1_row0" class="row_heading level1 row0" >coords+demo+radio</th>
#       <td id="T_4186d_row0_col0" class="data row0 col0" >—</td>
#       <td id="T_4186d_row0_col1" class="data row0 col1" >0.0030</td>
#       <td id="T_4186d_row0_col2" class="data row0 col2" >0.0502</td>
#       <td id="T_4186d_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_4186d_row0_col4" class="data row0 col4" >0.0328</td>
#       <td id="T_4186d_row0_col5" class="data row0 col5" >0.0077</td>
#       <td id="T_4186d_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_4186d_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_4186d_row0_col8" class="data row0 col8" >0.0001</td>
#     </tr>
#     <tr>
#       <th id="T_4186d_level1_row1" class="row_heading level1 row1" >demo+radio</th>
#       <td id="T_4186d_row1_col0" class="data row1 col0" >0.0030</td>
#       <td id="T_4186d_row1_col1" class="data row1 col1" >—</td>
#       <td id="T_4186d_row1_col2" class="data row1 col2" >0.4474</td>
#       <td id="T_4186d_row1_col3" class="data row1 col3" >0.0060</td>
#       <td id="T_4186d_row1_col4" class="data row1 col4" >0.9467</td>
#       <td id="T_4186d_row1_col5" class="data row1 col5" >0.4900</td>
#       <td id="T_4186d_row1_col6" class="data row1 col6" >0.0042</td>
#       <td id="T_4186d_row1_col7" class="data row1 col7" >0.0004</td>
#       <td id="T_4186d_row1_col8" class="data row1 col8" >0.0069</td>
#     </tr>
#     <tr>
#       <th id="T_4186d_level1_row2" class="row_heading level1 row2" >coords+radio</th>
#       <td id="T_4186d_row2_col0" class="data row2 col0" >0.0502</td>
#       <td id="T_4186d_row2_col1" class="data row2 col1" >0.4474</td>
#       <td id="T_4186d_row2_col2" class="data row2 col2" >—</td>
#       <td id="T_4186d_row2_col3" class="data row2 col3" >0.0010</td>
#       <td id="T_4186d_row2_col4" class="data row2 col4" >0.5655</td>
#       <td id="T_4186d_row2_col5" class="data row2 col5" >0.2855</td>
#       <td id="T_4186d_row2_col6" class="data row2 col6" >0.0002</td>
#       <td id="T_4186d_row2_col7" class="data row2 col7" >0.0000</td>
#       <td id="T_4186d_row2_col8" class="data row2 col8" >0.0082</td>
#     </tr>
#     <tr>
#       <th id="T_4186d_level1_row3" class="row_heading level1 row3" >radiomics</th>
#       <td id="T_4186d_row3_col0" class="data row3 col0" >0.0000</td>
#       <td id="T_4186d_row3_col1" class="data row3 col1" >0.0060</td>
#       <td id="T_4186d_row3_col2" class="data row3 col2" >0.0010</td>
#       <td id="T_4186d_row3_col3" class="data row3 col3" >—</td>
#       <td id="T_4186d_row3_col4" class="data row3 col4" >0.0295</td>
#       <td id="T_4186d_row3_col5" class="data row3 col5" >0.0837</td>
#       <td id="T_4186d_row3_col6" class="data row3 col6" >0.5921</td>
#       <td id="T_4186d_row3_col7" class="data row3 col7" >0.2017</td>
#       <td id="T_4186d_row3_col8" class="data row3 col8" >0.5516</td>
#     </tr>
#     <tr>
#       <th id="T_4186d_level0_row4" class="row_heading level0 row4" rowspan="5">AdaBoost</th>
#       <th id="T_4186d_level1_row4" class="row_heading level1 row4" >coords+demo+radio</th>
#       <td id="T_4186d_row4_col0" class="data row4 col0" >0.0328</td>
#       <td id="T_4186d_row4_col1" class="data row4 col1" >0.9467</td>
#       <td id="T_4186d_row4_col2" class="data row4 col2" >0.5655</td>
#       <td id="T_4186d_row4_col3" class="data row4 col3" >0.0295</td>
#       <td id="T_4186d_row4_col4" class="data row4 col4" >—</td>
#       <td id="T_4186d_row4_col5" class="data row4 col5" >0.0919</td>
#       <td id="T_4186d_row4_col6" class="data row4 col6" >0.0035</td>
#       <td id="T_4186d_row4_col7" class="data row4 col7" >0.0003</td>
#       <td id="T_4186d_row4_col8" class="data row4 col8" >0.0006</td>
#     </tr>
#     <tr>
#       <th id="T_4186d_level1_row5" class="row_heading level1 row5" >demo+radio</th>
#       <td id="T_4186d_row5_col0" class="data row5 col0" >0.0077</td>
#       <td id="T_4186d_row5_col1" class="data row5 col1" >0.4900</td>
#       <td id="T_4186d_row5_col2" class="data row5 col2" >0.2855</td>
#       <td id="T_4186d_row5_col3" class="data row5 col3" >0.0837</td>
#       <td id="T_4186d_row5_col4" class="data row5 col4" >0.0919</td>
#       <td id="T_4186d_row5_col5" class="data row5 col5" >—</td>
#       <td id="T_4186d_row5_col6" class="data row5 col6" >0.0198</td>
#       <td id="T_4186d_row5_col7" class="data row5 col7" >0.0016</td>
#       <td id="T_4186d_row5_col8" class="data row5 col8" >0.0046</td>
#     </tr>
#     <tr>
#       <th id="T_4186d_level1_row6" class="row_heading level1 row6" >coords+radio</th>
#       <td id="T_4186d_row6_col0" class="data row6 col0" >0.0000</td>
#       <td id="T_4186d_row6_col1" class="data row6 col1" >0.0042</td>
#       <td id="T_4186d_row6_col2" class="data row6 col2" >0.0002</td>
#       <td id="T_4186d_row6_col3" class="data row6 col3" >0.5921</td>
#       <td id="T_4186d_row6_col4" class="data row6 col4" >0.0035</td>
#       <td id="T_4186d_row6_col5" class="data row6 col5" >0.0198</td>
#       <td id="T_4186d_row6_col6" class="data row6 col6" >—</td>
#       <td id="T_4186d_row6_col7" class="data row6 col7" >0.4938</td>
#       <td id="T_4186d_row6_col8" class="data row6 col8" >0.8666</td>
#     </tr>
#     <tr>
#       <th id="T_4186d_level1_row7" class="row_heading level1 row7" >radiomics</th>
#       <td id="T_4186d_row7_col0" class="data row7 col0" >0.0000</td>
#       <td id="T_4186d_row7_col1" class="data row7 col1" >0.0004</td>
#       <td id="T_4186d_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_4186d_row7_col3" class="data row7 col3" >0.2017</td>
#       <td id="T_4186d_row7_col4" class="data row7 col4" >0.0003</td>
#       <td id="T_4186d_row7_col5" class="data row7 col5" >0.0016</td>
#       <td id="T_4186d_row7_col6" class="data row7 col6" >0.4938</td>
#       <td id="T_4186d_row7_col7" class="data row7 col7" >—</td>
#       <td id="T_4186d_row7_col8" class="data row7 col8" >0.8262</td>
#     </tr>
#     <tr>
#       <th id="T_4186d_level1_row8" class="row_heading level1 row8" >demographic only</th>
#       <td id="T_4186d_row8_col0" class="data row8 col0" >0.0001</td>
#       <td id="T_4186d_row8_col1" class="data row8 col1" >0.0069</td>
#       <td id="T_4186d_row8_col2" class="data row8 c

# %% [markdown]
# # bar plots

# %%
from pathlib import Path

def build_metric_by_config_from_json(
    results_dir,
    methods_list,
    metric_key="f1_score",
    ml_models=("AdaBoost", "TabPFN"),
    file_name="results_fold",
):
    """
    Collects a scalar metric per fold from your JSON files.

    Returns:
      config_to_method_vals: dict
        {
          "coords+demo+radiomics": {"deep_sets":[..5..], "TabPFN":[..5..], ...},
          "demo+radiomics": {...},
          "coords+radiomics": {...},
          "radiomics": {...},
        }
    """

    configs = [
        (True,  True,  "coords+demo+radiomics"),
        (False, True,  "demo+radiomics"),
        (True,  False, "coords+radiomics"),
        (False, False, "radiomics"),
    ]

    config_to_method_vals = {}

    for use_coords, use_demographic, cfg_name in configs:
        method_vals = {}
        ml_vals = {}

        for method in methods_list:
            # same folder naming as your code
            if use_demographic and use_coords:
                folder_name = f"{method}_coords_demographic_radiomics"
            elif use_demographic and not use_coords:
                folder_name = f"{method}_demographic_radiomics"
            elif not use_demographic and use_coords:
                folder_name = f"{method}_coords_radiomics"
            else:
                folder_name = f"{method}_radiomics"

            for i in range(5):
                fold_path = Path(results_dir) / folder_name / f"fold_{i}" / f"{file_name}_{i}.json"
                fold_results = load_json(str(fold_path))

                if method == "ml_models":
                    for mm in ml_models:
                        if metric_key not in fold_results.get(mm, {}):
                            raise KeyError(
                                f"Missing metric '{metric_key}' in fold_results['{mm}'] at: {fold_path}"
                            )
                        ml_vals.setdefault(mm, [])
                        ml_vals[mm].append(float(fold_results[mm][metric_key]))
                else:
                    if metric_key not in fold_results:
                        raise KeyError(
                            f"Missing metric '{metric_key}' in fold_results at: {fold_path}"
                        )
                    method_vals.setdefault(method, [])
                    method_vals[method].append(float(fold_results[metric_key]))

        method_vals.update(ml_vals)
        config_to_method_vals[cfg_name] = method_vals
        # reorder for consistent plotting
        config_to_method_vals[cfg_name] = {k: method_vals[k] for k in ['transformer', 'deep_sets', 'mil', 'set_transformer', 'graph', 'AdaBoost', 'TabPFN']}
    return config_to_method_vals

def plot_grouped_metric_boxplots(
    config_to_method_vals,
    metric_name="F1-score",
    title=None,
    group_order=("coords+demo+radiomics", "demo+radiomics", "coords+radiomics", "radiomics"),
    ylim=None,
    figsize=(16, 7),
    savepath=None,
    dpi=300,
):
    # all_methods = sorted({m for cfg in config_to_method_vals.values() for m in cfg.keys()})
    all_methods = list(config_to_method_vals[group_order[0]].keys())
    plt.rcParams.update({
        "font.size": 12,
        "axes.titlesize": 14,
        "axes.labelsize": 12,
        "legend.fontsize": 10,
        "axes.spines.top": False,
        "axes.spines.right": False,
    })

    # if title is None:
        # title = f"{metric_name} (5-Fold CV) by Feature Configuration"

    fig, ax = plt.subplots(figsize=figsize)
    ax.set_title(title, pad=12)
    ax.set_ylabel(metric_name)

    if ylim is not None:
        ax.set_ylim(*ylim)

    ax.grid(True, axis="y", alpha=0.25)
    ax.minorticks_on()
    ax.grid(True, which="minor", axis="y", alpha=0.10)

    box_w = 0.55
    inner_gap = 0.22
    group_gap = 1.2

    cmap = plt.get_cmap("tab10")
    method_to_color = {m: cmap(i % 10) for i, m in enumerate(all_methods)}

    positions, data, box_colors = [], [], []
    positions_methods = []
    group_centers = []
    group_boundaries = []
    x = 0.0

    for cfg_name in group_order:
        start = x

        for method in all_methods:
            vals = config_to_method_vals.get(cfg_name, {}).get(method, [])
            if len(vals) == 0:
                x += (box_w + inner_gap)
                continue

            positions.append(x)
            data.append(vals)
            box_colors.append(method_to_color[method])
            positions_methods.append(method)
            x += (box_w + inner_gap)

        end = x - (box_w + inner_gap)
        group_centers.append((start + end) / 2.0)
        group_boundaries.append(x + group_gap / 2.0)
        x += group_gap

    bp = ax.boxplot(
        data,
        positions=positions,
        widths=box_w,
        patch_artist=True,
        showfliers=False,
        medianprops=dict(linewidth=2.0),
        whiskerprops=dict(linewidth=1.5),
        capprops=dict(linewidth=1.5),
        boxprops=dict(linewidth=1.5),
    )

    for patch, c in zip(bp["boxes"], box_colors):
        patch.set_facecolor(c)
        patch.set_alpha(0.22)

    # jittered fold points
    rng = np.random.default_rng(0)
    for pos, vals, c in zip(positions, data, box_colors):
        vals = np.asarray(vals, dtype=float)
        jitter = rng.normal(loc=0.0, scale=0.055, size=len(vals))
        ax.scatter(
            np.full_like(vals, pos) + jitter,
            vals,
            s=28,
            alpha=0.8,
            edgecolors="none",
            color=c,
            zorder=3,
        )

    # Bottom axis: 4 configuration labels
    ax.set_xticks(group_centers)
    ax.set_xticklabels(group_order)
    ax.set_xlabel("Feature configuration")

    for boundary in group_boundaries[:-1]:
        ax.axvline(boundary, lw=1.0, alpha=0.12)

    # Top axis: method labels aligned to each box
    ax_top = ax.twiny()
    ax_top.set_xlim(ax.get_xlim())
    ax_top.set_xticks(positions)
    ax_top.set_xticklabels(positions_methods, rotation=60, ha="left")
    ax_top.set_xlabel("Models")
    ax_top.tick_params(axis="x", length=0, pad=6)

    # Legend (optional; remove if you prefer)
    handles = [
        plt.Line2D([0], [0], marker="s", linestyle="", markersize=10,
                   markerfacecolor=method_to_color[m], alpha=0.6, label=m)
        for m in all_methods
    ]
    # ax.legend(handles=handles, title="Methods", loc="upper right", frameon=True, framealpha=0.9)

    fig.tight_layout()

    if savepath is not None:
        fig.savefig(savepath, dpi=dpi, bbox_inches="tight")

    plt.show()

vals = build_metric_by_config_from_json(
    results_dir="../Results",
    methods_list=models,
    metric_key="f1_score",
    ml_models=("AdaBoost", "TabPFN"),
)
plot_grouped_metric_boxplots(vals, metric_name="F1-score", ylim=(0.6, 1.02), savepath="figures/f1_score_boxplot_center1.png")

vals = build_metric_by_config_from_json(
    results_dir="../Results",
    methods_list=models,
    metric_key="roc_auc",
    ml_models=("AdaBoost", "TabPFN"),
)
plot_grouped_metric_boxplots(vals, metric_name="ROC-AUC", ylim=(0.6, 1.02), savepath="figures/roc_auc_boxplot_center1.png")
vals = build_metric_by_config_from_json(
    results_dir="../Results",
    methods_list=models,
    metric_key="accuracy",
    ml_models=("AdaBoost", "TabPFN"),
)
plot_grouped_metric_boxplots(vals, metric_name="Accuracy", ylim=(0.6, 1.02), savepath="figures/accuracy_boxplot_center1.png")

# %% [markdown]
# # Test time adaptation

# %%
print("raw inference")
selected_methods_table("../Results", models, use_coords=True, use_demographic=True, ml_models=["AdaBoost", 'TabPFN'], file_name="center2_aggregated_results.json")
print("tta norm")
selected_methods_table("../Results", new_models, use_coords=True, use_demographic=True, ml_models=[''], file_name="tta_norm_center2_aggregated_results.json")
print("tta tent")
selected_methods_table("../Results", new_models, use_coords=True, use_demographic=True, ml_models=[''], file_name="tta_tent_center2_aggregated_results.json")

# %%
vals = build_metric_by_config_from_json(
    results_dir="../Results",
    methods_list=models,
    metric_key="roc_auc",
    ml_models=("AdaBoost", "TabPFN"),
    file_name="center2_results_fold",
)
plot_grouped_metric_boxplots(vals, metric_name="roc_auc", ylim=(0.4, 1.02))

# %%
from pathlib import Path
import json
import numpy as np
import matplotlib.pyplot as plt


def load_json(path: str):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)


def plot_methodwise_grouped_versions_boxplots_from_folds(
    results_dir,
    deep_methods,
    metric_key="f1_score",
    folds=(0, 1, 2, 3, 4),
    group_order=("coords+demo+radiomics", "demo+radiomics", "coords+radiomics", "radiomics"),
    # group -> suffix exactly matching your folders
    group_to_suffix=None,
    # version name -> filename template inside fold folder
    versions=(
        ("Base (center2)", "center2_results_fold_{i}.json"),
        ("TTA-Norm",       "tta_norm_center2_results_fold_{i}.json"),
        ("TENT",           "tta_tent_center2_results_fold_{i}.json"),
    ),
    file_name="results_fold",  # not used here (kept for compatibility if you extend)
    file_must_exist=True,
    figsize_per_method=5.5,
    ylim=(0, 1.02),
    show_points=True,
    show_legend=True,
    add_separators=True,
    separator_style=None,
    savepath=None,
    dpi=300,
):
    """
    Expected structure like:
      Results/
        deep_sets_demographic_radiomics/
          fold_0/
            center2_results_fold_0.json
            tta_norm_center2_results_fold_0.json
            tta_tent_center2_results_fold_0.json
            ...
          fold_1/...
        deep_sets_coords_demographic_radiomics/...

    Plot:
      1 x N_methods subplots
      Each subplot: 4 groups on x-axis; within each group 3 boxplots (Base/TTA-Norm/TENT)
      Vertical "fancy" separator lines between group blocks (after each 3-box block).
    """

    if group_to_suffix is None:
        group_to_suffix = {
            "coords+demo+radiomics": "coords_demographic_radiomics",
            "demo+radiomics":        "demographic_radiomics",
            "coords+radiomics":      "coords_radiomics",
            "radiomics":             "radiomics",
        }

    # Default separator style
    if separator_style is None:
        separator_style = dict(
            linewidth=2.0,
            linestyles=(0, (4, 6)),  # dashed: 4 on, 6 off
            alpha=0.18,
            zorder=0
        )

    n_methods = len(deep_methods)
    fig, axes = plt.subplots(
        1, n_methods,
        figsize=(figsize_per_method * n_methods, 6.6),
        sharey=True
    )
    if n_methods == 1:
        axes = [axes]

    plt.rcParams.update({
        "font.size": 12,
        "axes.titlesize": 14,
        "axes.labelsize": 12,
        "legend.fontsize": 10,
        "axes.spines.top": False,
        "axes.spines.right": False,
    })

    # Layout: per group, 3 boxes
    n_versions = len(versions)
    base_positions = np.arange(len(group_order))  # group centers: 0..3
    group_width = 0.80
    box_w = group_width / (n_versions + 0.8)
    offsets = np.linspace(-group_width/2 + box_w/2, group_width/2 - box_w/2, n_versions)

    # Colors per version
    cmap = plt.get_cmap("tab10")
    version_colors = {vname: cmap(i % 10) for i, (vname, _) in enumerate(versions)}

    rng = np.random.default_rng(0)

    def folder_for(method, group):
        return f"{method}_{group_to_suffix[group]}"

    def file_for(version_template, i):
        return version_template.format(i=i)

    # One shared legend for the whole figure
    legend_handles = [
        plt.Line2D([0], [0], marker="s", linestyle="", markersize=10,
                   markerfacecolor=version_colors[vname], alpha=0.6, label=vname)
        for vname, _ in versions
    ]

    for ax, method in zip(axes, deep_methods):
        ax.set_title(method)
        ax.grid(True, axis="y", alpha=0.25)
        ax.minorticks_on()
        ax.grid(True, which="minor", axis="y", alpha=0.10)

        all_data = []
        all_pos = []
        all_cols = []
        group_boundaries = []  # x positions for separators between group blocks

        # Collect data in order: group-major, version-minor
        for gi, group in enumerate(group_order):
            folder = Path(results_dir) / folder_for(method, group)

            group_pos = []  # x positions of the 3 version boxes in this group

            for vi, (vname, vtemplate) in enumerate(versions):
                vals = []
                for i in folds:
                    fold_dir = folder / f"fold_{i}"
                    fpath = fold_dir / file_for(vtemplate, i)

                    if not fpath.exists():
                        if file_must_exist:
                            raise FileNotFoundError(
                                f"Missing file: {fpath}\n"
                                f"Expected under: {fold_dir}\n"
                                f"Check templates in `versions=`."
                            )
                        else:
                            continue

                    d = load_json(str(fpath))
                    if metric_key not in d:
                        raise KeyError(f"Missing '{metric_key}' in {fpath}")

                    vals.append(float(d[metric_key]))

                pos = base_positions[gi] + offsets[vi]
                group_pos.append(pos)

                all_data.append(vals)
                all_pos.append(pos)
                all_cols.append(version_colors[vname])

            # boundary between this group and next group (except last group)
            if gi < len(group_order) - 1:
                rightmost = max(group_pos)
                leftmost_next = base_positions[gi + 1] + min(offsets)
                boundary_x = (rightmost + leftmost_next) / 2.0
                group_boundaries.append(boundary_x)

        bp = ax.boxplot(
            all_data,
            positions=all_pos,
            widths=box_w,
            patch_artist=True,
            showfliers=False,
            medianprops=dict(linewidth=2.0),
            whiskerprops=dict(linewidth=1.4),
            capprops=dict(linewidth=1.4),
            boxprops=dict(linewidth=1.4),
        )

        for patch, c in zip(bp["boxes"], all_cols):
            patch.set_facecolor(c)
            patch.set_alpha(0.22)

        if show_points:
            for pos, vals, c in zip(all_pos, all_data, all_cols):
                vals = np.asarray(vals, dtype=float)
                jitter = rng.normal(loc=0.0, scale=box_w * 0.12, size=len(vals))
                ax.scatter(
                    np.full_like(vals, pos) + jitter,
                    vals,
                    s=26,
                    alpha=0.82,
                    edgecolors="none",
                    color=c,
                    zorder=3,
                )

        # Fancy vertical separators between 3-box blocks (group boundaries)
        if add_separators and len(group_boundaries) > 0:
            # Ensure y-lims are set before drawing full-height separators
            if ylim is not None:
                ax.set_ylim(*ylim)
            y0, y1 = ax.get_ylim()
            for xsep in group_boundaries:
                ax.vlines(xsep, y0, y1, **separator_style)

        ax.set_xticks(base_positions)
        ax.set_xticklabels(group_order, rotation=18, ha="right")
        ax.set_xlabel("Feature configuration")

        if ylim is not None:
            ax.set_ylim(*ylim)

    axes[0].set_ylabel(metric_key)

    if show_legend:
        fig.legend(
            handles=legend_handles,
            title="Version",
            loc="lower center",
            ncol=len(versions),
            frameon=True,
            framealpha=0.9,
            bbox_to_anchor=(0.5, 1.03),
        )

    fig.tight_layout()

    if savepath is not None:
        fig.savefig(savepath, dpi=dpi, bbox_inches="tight")

    plt.show()




plot_methodwise_grouped_versions_boxplots_from_folds(
    results_dir="../Results",
    deep_methods=new_models,
    metric_key="f1_score",             
    savepath="figures/center2_tta_f1score.png",
)

plot_methodwise_grouped_versions_boxplots_from_folds(
    results_dir="../Results",
    deep_methods=new_models,
    metric_key="roc_auc",             
    savepath="figures/center2_tta_rocauc.png",
)

# %%
from pathlib import Path
import json
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import ttest_rel


def load_json(path: str):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)


def p_to_stars(p: float) -> str:
    if not np.isfinite(p):
        return ""
    if p < 1e-4:
        return "****"
    if p < 1e-3:
        return "***"
    if p < 1e-2:
        return "**"
    if p < 5e-2:
        return "*"
    return ""  # IMPORTANT: no 'ns'


def holm_adjust(pvals):
    pvals = np.asarray(pvals, dtype=float)
    finite = np.isfinite(pvals)
    out = np.full_like(pvals, np.nan, dtype=float)
    if finite.sum() == 0:
        return out

    idx = np.where(finite)[0]
    p = pvals[finite]
    order = np.argsort(p)
    p_sorted = p[order]

    adj_sorted = np.empty_like(p_sorted)
    running_max = 0.0
    m = len(p_sorted)
    for i, p_i in enumerate(p_sorted):
        factor = (m - i)
        running_max = max(running_max, factor * p_i)
        adj_sorted[i] = running_max

    adj_sorted = np.minimum(adj_sorted, 1.0)

    inv = np.empty_like(order)
    inv[order] = np.arange(m)
    out[idx] = adj_sorted[inv]
    return out


def paired_t_pvalue(a, b, alternative="two-sided"):
    a = np.asarray(a, dtype=float)
    b = np.asarray(b, dtype=float)

    if len(a) == 0 or len(b) == 0:
        return np.nan
    if len(a) != len(b):
        raise ValueError(f"Paired t-test requires equal length, got {len(a)} vs {len(b)}")

    res = ttest_rel(a, b)
    p_two = float(res.pvalue)

    if alternative == "two-sided":
        return p_two

    diff_mean = float(np.mean(a - b))
    p_one = p_two / 2.0

    if alternative == "greater":
        return p_one if diff_mean > 0 else 1.0 - p_one
    if alternative == "less":
        return p_one if diff_mean < 0 else 1.0 - p_one

    raise ValueError("alternative must be 'two-sided', 'greater', or 'less'")


def add_sig_bracket(ax, x1, x2, y, h, text, lw=1.2, alpha=0.9, fontsize=14):
    ax.plot([x1, x1, x2, x2], [y, y + h, y + h, y],
            lw=lw, alpha=alpha, color="black", clip_on=False)
    ax.text((x1 + x2) / 2, y + h, text,
            ha="center", va="bottom", fontsize=fontsize, color="black", clip_on=False)


def plot_methodwise_grouped_versions_boxplots_from_folds(
    results_dir,
    deep_methods,
    metric_key="f1_score",
    folds=(0, 1, 2, 3, 4),
    group_order=("coords+demo+radiomics", "demo+radiomics", "coords+radiomics", "radiomics"),
    group_to_suffix=None,
    versions=(
        ("Base (center2)", "center2_results_fold_{i}.json"),
        ("TTA-Norm",       "tta_norm_center2_results_fold_{i}.json"),
        ("TENT",           "tta_tent_center2_results_fold_{i}.json"),
    ),
    file_must_exist=True,
    figsize_per_method=5.5,
    ylim=(0, 1.02),
    show_points=True,
    show_legend=True,
    add_separators=True,
    separator_style=None,
    # --- p-value annotations (paired t-test + Holm) ---
    add_pvalues=False,
    alpha=0.05,
    pvalue_pairs=((0, 1), (0, 2), (1, 2)),
    pvalue_alternative="two-sided",     # "two-sided", "greater", or "less"
    holm_scope="within_group",          # "within_group" or "within_method"
    pvalue_bracket_height=0.010,        # fraction of y-range
    pvalue_step=0.045,                  # fraction of y-range
    pvalue_fontsize=14,
    savepath=None,
    dpi=300,
):
    if group_to_suffix is None:
        group_to_suffix = {
            "coords+demo+radiomics": "coords_demographic_radiomics",
            "demo+radiomics":        "demographic_radiomics",
            "coords+radiomics":      "coords_radiomics",
            "radiomics":             "radiomics",
        }

    if separator_style is None:
        separator_style = dict(
            linewidth=2.0,
            linestyles=(0, (4, 6)),
            alpha=0.18,
            zorder=0
        )

    n_methods = len(deep_methods)
    fig, axes = plt.subplots(
        1, n_methods,
        figsize=(figsize_per_method * n_methods, 6.6),
        sharey=True
    )
    if n_methods == 1:
        axes = [axes]

    plt.rcParams.update({
        "font.size": 12,
        "axes.titlesize": 14,
        "axes.labelsize": 12,
        "legend.fontsize": 10,
        "axes.spines.top": False,
        "axes.spines.right": False,
    })

    n_versions = len(versions)
    base_positions = np.arange(len(group_order))
    group_width = 0.80
    box_w = group_width / (n_versions + 0.8)
    offsets = np.linspace(-group_width/2 + box_w/2, group_width/2 - box_w/2, n_versions)

    cmap = plt.get_cmap("tab10")
    version_colors = {vname: cmap(i % 10) for i, (vname, _) in enumerate(versions)}
    rng = np.random.default_rng(0)

    def folder_for(method, group):
        return f"{method}_{group_to_suffix[group]}"

    def file_for(version_template, i):
        return version_template.format(i=i)

    legend_handles = [
        plt.Line2D([0], [0], marker="s", linestyle="", markersize=10,
                   markerfacecolor=version_colors[vname], alpha=0.6, label=vname)
        for vname, _ in versions
    ]

    for ax, method in zip(axes, deep_methods):
        ax.set_title(method)
        ax.grid(True, axis="y", alpha=0.25)
        ax.minorticks_on()
        ax.grid(True, which="minor", axis="y", alpha=0.10)

        all_data, all_pos, all_cols = [], [], []
        group_boundaries = []

        group_version_vals = {g: {} for g in group_order}
        group_version_pos  = {g: {} for g in group_order}

        for gi, group in enumerate(group_order):
            folder = Path(results_dir) / folder_for(method, group)
            group_pos = []

            for vi, (vname, vtemplate) in enumerate(versions):
                vals = []
                for i in folds:
                    fold_dir = folder / f"fold_{i}"
                    fpath = fold_dir / file_for(vtemplate, i)

                    if not fpath.exists():
                        if file_must_exist:
                            raise FileNotFoundError(f"Missing file: {fpath}")
                        else:
                            continue

                    d = load_json(str(fpath))
                    if metric_key not in d:
                        raise KeyError(f"Missing '{metric_key}' in {fpath}")
                    vals.append(float(d[metric_key]))

                pos = base_positions[gi] + offsets[vi]
                group_pos.append(pos)

                all_data.append(vals)
                all_pos.append(pos)
                all_cols.append(version_colors[vname])

                group_version_vals[group][vi] = vals
                group_version_pos[group][vi] = pos

            if gi < len(group_order) - 1:
                rightmost = max(group_pos)
                leftmost_next = base_positions[gi + 1] + min(offsets)
                group_boundaries.append((rightmost + leftmost_next) / 2.0)

        bp = ax.boxplot(
            all_data,
            positions=all_pos,
            widths=box_w,
            patch_artist=True,
            showfliers=False,
            medianprops=dict(linewidth=2.0),
            whiskerprops=dict(linewidth=1.4),
            capprops=dict(linewidth=1.4),
            boxprops=dict(linewidth=1.4),
        )

        for patch, c in zip(bp["boxes"], all_cols):
            patch.set_facecolor(c)
            patch.set_alpha(0.22)

        if show_points:
            for pos, vals, c in zip(all_pos, all_data, all_cols):
                vals = np.asarray(vals, dtype=float)
                jitter = rng.normal(loc=0.0, scale=box_w * 0.12, size=len(vals))
                ax.scatter(
                    np.full_like(vals, pos) + jitter,
                    vals,
                    s=26,
                    alpha=0.82,
                    edgecolors="none",
                    color=c,
                    zorder=3,
                )

        if ylim is not None:
            ax.set_ylim(*ylim)

        if add_separators and len(group_boundaries) > 0:
            y0, y1 = ax.get_ylim()
            for xsep in group_boundaries:
                ax.vlines(xsep, y0, y1, **separator_style)

        ax.set_xticks(base_positions)
        ax.set_xticklabels(group_order, rotation=18, ha="right")
        ax.set_xlabel("Feature configuration")

        # ---- ONLY annotate significant comparisons (no ns, no brackets for ns) ----
        if add_pvalues:
            y0, y1 = ax.get_ylim()
            y_range = y1 - y0

            # raw p-values per group
            raw_p_by_group = {}
            for group in group_order:
                raw = []
                for (a_idx, b_idx) in pvalue_pairs:
                    a = group_version_vals[group].get(a_idx, [])
                    b = group_version_vals[group].get(b_idx, [])
                    p = paired_t_pvalue(a, b, alternative=pvalue_alternative)
                    raw.append(p)
                raw_p_by_group[group] = raw

            # Holm adjustment
            if holm_scope == "within_group":
                adj_p_by_group = {g: holm_adjust(raw_p_by_group[g]) for g in group_order}
            elif holm_scope == "within_method":
                flat, back = [], []
                for g in group_order:
                    for k, p in enumerate(raw_p_by_group[g]):
                        flat.append(p)
                        back.append((g, k))
                flat_adj = holm_adjust(flat)
                adj_p_by_group = {g: [np.nan] * len(pvalue_pairs) for g in group_order}
                for adj, (g, k) in zip(flat_adj, back):
                    adj_p_by_group[g][k] = adj
            else:
                raise ValueError("holm_scope must be 'within_group' or 'within_method'")

            # draw only significant
            for group in group_order:
                max_in_group = max(np.max(group_version_vals[group][vi]) for vi in group_version_vals[group])
                base_y = max_in_group + 0.04 * y_range
                level = 0  # stack only significant ones

                for (a_idx, b_idx), p_adj in zip(pvalue_pairs, adj_p_by_group[group]):
                    if not np.isfinite(p_adj) or p_adj >= alpha:
                        continue  # SKIP non-significant

                    stars = p_to_stars(p_adj)
                    if stars == "":
                        continue

                    x1 = group_version_pos[group][a_idx]
                    x2 = group_version_pos[group][b_idx]
                    y = base_y + level * (pvalue_step * y_range)

                    add_sig_bracket(
                        ax, x1, x2,
                        y=y,
                        h=pvalue_bracket_height * y_range,
                        text=stars,
                        lw=1.1,
                        alpha=0.9,
                        fontsize=pvalue_fontsize,
                    )
                    level += 1  # only increment when we draw something

    axes[0].set_ylabel(metric_key)

    if show_legend:
        fig.legend(
            handles=legend_handles,
            title="Version",
            loc="upper center",
            ncol=len(versions),
            frameon=True,
            framealpha=0.9,
            bbox_to_anchor=(0.5, 1.03),
        )

    fig.tight_layout()

    if savepath is not None:
        fig.savefig(savepath, dpi=dpi, bbox_inches="tight")

    plt.show()



plot_methodwise_grouped_versions_boxplots_from_folds(
    results_dir="../Results",
    deep_methods=new_models,
    metric_key="f1_score",
    add_pvalues=True,
    pvalue_pairs=((0, 1), (0, 2), (1,2)),     # compare vs Base only (cleaner)
    pvalue_alternative="less",      # if you call paired_t_pvalue(improved, base); see below note
    holm_scope="within_group",
    savepath="figures/f1_boxplots_ttest_holm_center2.png",
)

plot_methodwise_grouped_versions_boxplots_from_folds(
    results_dir="../Results",
    deep_methods=new_models,
    metric_key="roc_auc",
    add_pvalues=True,
    pvalue_pairs=((0, 1), (0, 2), (1,2)),     # compare vs Base only (cleaner)
    pvalue_alternative="less",      # if you call paired_t_pvalue(improved, base); see below note
    holm_scope="within_group",
    savepath="figures/roc_auc_boxplots_ttest_holm_center2.png",
)
